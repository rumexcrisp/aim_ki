# %%
import matplotlib.pyplot as plt
import numpy as np

N = 10
s = 0.5 # strength of noise
x = np.linspace(0, 1, N)
e = np.random.normal(0, s, N)

y = np.sin(2*np.pi*x) + e
plt.scatter(x,y)

p_hat = np.polyfit(x, np.sin(2*np.pi*x), 6)

# for plotting
xx = np.linspace(0,1, 100)
plt.plot(xx, np.sin(2*np.pi*xx))

# now add noise
# e = np.random
y = y+e
